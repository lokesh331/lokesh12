# %% [markdown]
# <a href="https://colab.research.google.com/github/lokesh331/lokesh12/blob/main/31_1_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
import pandas as pd
df=pd.read_csv('NewspaperData.csv')
print(df)
# Out:
#      <input type="file" id="files-2489ed8e-9a8f-4978-8841-b9354820cde9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2489ed8e-9a8f-4978-8841-b9354820cde9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.shape
# Out:
# (34, 3)

# %%
df_new = df[["daily","sunday"]]
df_new.corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %%
import seaborn as sns
sns.scatterplot(df_new)
sns.pairplot(df_new)
sns.heatmap(df_new.corr(), annot=True)
sns.histplot(df_new)
sns.distplot(df_new)
sns.boxplot(df_new)
sns.violinplot(df_new)
sns.countplot(df_new)
# Out:
# <ipython-input-27-8e010d5d53a3>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_new)
# <Axes: ylabel='Count'>

# %%
import statsmodels.formula.api as smf

model1 = smf.ols("sunday ~ daily", data=df_new).fit()
sns.regplot(x="daily", y="sunday", data=df_new);
